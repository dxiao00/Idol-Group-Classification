# %%
import numpy as np 
import pandas as pd 
df = pd.read_csv('kpop_2013_2021.csv')

# %%
idol_group_artists = ['EXO', '4Minute', 'SHINee', "Girls' Generation", 'f(x)', '2AM',
       'miss A', "Girl's Day", 'VIXX', 'Secret', 'EXID', 'EXO-K',
       'Block B', 'WINNER', '2NE1', 'Beast', 'BIGBANG', 'BTS',
       'Wonder Girls', 'iKON', 'Red Velvet', 'SUPER JUNIOR', 'TWICE',
       'PRODUCE 101', 'BLACKPINK', 'MAMAMOO', 'I.O.I', 'Wanna One',
       'GOT7', 'NCT 127', 'NCT DREAM', 'IZ*ONE', '(G)I-DLE', 'Monsta X',
       'Stray Kids', 'LOONA', "NU'EST W", 'fromis_9', 'NCT, NCT U',
       'K/DA, Madison Beer, (G)I-DLE, Jaira Burns, League of Legends',
       'gugudan', 'Dreamcatcher', 'LABOUM', 'ATEEZ',
       'SUPER JUNIOR, Leslie Grace, Play-N-Skillz', 'BTS, Nicki Minaj',
       'H.I.N.P (Hot Issue of Ntl. Producers)', 'PRODUCE 48',
       "Girls' Generation-Oh!GG", 'SEULGI, CHUNG HA, SinB, JEON SOYEON',
       'BTS, Halsey', 'ITZY', 'EVERGLOW', 'SEVENTEEN',
       'TOMORROW X TOGETHER', 'Monsta X, French Montana', 'Apink',
       'SuperM', 'CLC', 'ASTRO', 'NCT DREAM, HRVY', 'KARD', 'PENTAGON',
       'AOA', 'X1', 'MOMOLAND', 'AB6IX', 'BLACKPINK, Selena Gomez',
       'NCT U', 'Red Velvet - IRENE & SEULGI', 'aespa', 'OH MY GIRL',
       'BLACKPINK, Cardi B',
       'K/DA, (G)I-DLE, Wolftyla, Bea Miller, League of Legends',
       'GFRIEND', 'TREASURE', 'Lovelyz', '3YE', 'IVE', 'STAYC', 'Weeekly',
       'ENHYPEN', 'Brave Girls', 'Girls Planet 999', '7 LOVE Minutes',
       'Medusa', 'ONEUS']
non_idol_group_artists = ['G-DRAGON', 'Primary, Dynamicduo', 'Dynamicduo, Muzie', 'Lim Kim',
       'LeeHi', 'AKMU', 'Lee Seung Chul', 'Busker Busker', 'Roy Kim',
       'Cho Yong Pil', 'Seo In Guk', 'DAVICHI', '4MEN',
       'Verbal Jint, AILEE', 'Jay Park, Remastered',
       'Supreme Team, Crush', 'Lee Hyori', 'SUNMI', 'Geeks',
       'AKMU, 로빈, 이찬혁, LEE SUHYUN', 'SUNMI, Lena', 'TAEYANG',
       'Epik High, Joe Won Sun', 'Park Boram, ZICO', 'KYUHYUN',
       'GD X TAEYANG', 'HI SUHYUN, BOBBY', 'Jang Beom June',
       'Crush, Punch', 'Sung Si Kyung', 'Park Hyo Shin',
       'Jung Seung Hwan', 'M.C the Max', 'Hong Dae Kwang', 'Hyolyn',
       'Drunken Tiger, Yoon Mirae', '15&', 'Jun Hyo Seong',
       'TOY, Sung Si Kyung', 'Epik High, Younha', 'TAEYEON, Verbal Jint',
       'J.Y. Park', 'Crush, ZICO', 'ZICO, Babylon', 'Park Boram',
       'BoA, Gaeko', 'Baek Ji Young, Song Yu Vin', 'Naul',
       'DAVICHI, Mad Clown', 'Baek A Yeon', 'Zion.T',
       'Park Kyung, Park Boram', 'JONGHYUN, Zion.T', 'PSY, CL', 'BEN',
       'TAEYEON', 'Yerin Baek', 'BOL4', 'Yoon Mirae',
       'HEIZE, Yong Jun Hyung', 'ZICO', 'DEAN, Gaeko', 'BewhY, Jay Park',
       'Crush, TAEYEON', '10cm', 'OHHYUK', 'Gummy', 'WENDY, Eric Nam',
       'Sons of People', 'Zion.T, DJ Dopsh, G-DRAGON', 'HEIZE, nafla',
       'CHUNG HA, Nucksal', 'Woo, Loco, GRAY', 'DEAN, Yerin Baek',
       'Epik High, OHHYUK', 'PSY', 'HEIZE', 'Knock', 'Epik High, IU',
       'HEIZE, Shin Yong Jae', 'AILEE', 'TAEMIN', 'DAY6', 'Suzy',
       'CHUNG HA', 'JENNIE', 'HEIZE, Gaeko', 'RM', 'MINO', 'SHAUN',
       'DEAN, SULLI, Rad Museum', 'Zion.T, 슬기 (SEULGI)', 'Holland',
       'HAON, VINXEN', 'BoA', 'MeloMance', 'Punch', 'Lim Changjung',
       'j-hope', 'ZICO, IU', 'JONGHYUN', 'IU', 'SOMI', 'Hwa Sa',
       'j-hope, Becky G', 'BAEKHYUN', 'LeeHi, B.I', 'IU, SUGA', 'Agust D',
       'YooA', 'LISA', 'ROSÉ', 'JEON SOMI', 'HyunA', 'AKMU, IU',
       'HyunA&DAWN']

# %%
df['idol_group'] = df['artist/s'].apply(lambda x: 1 if x in idol_group_artists else 0)
df['idol_group'].value_counts()
# Out:
# idol_group
# 1    230
# 0    162
# Name: count, dtype: int64

# %%
df.to_csv('idol_classification.csv')

# %%
df['artist/s'].unique()
# Out:
# array(['EXO', '4Minute', 'G-DRAGON', 'SHINee', "Girls' Generation",
#        'f(x)', 'Primary, Dynamicduo', 'Dynamicduo, Muzie', 'Lim Kim',
#        'LeeHi', 'AKMU', 'Lee Seung Chul', 'Busker Busker', 'Roy Kim',
#        'Cho Yong Pil', 'Seo In Guk', 'DAVICHI', '2AM', '4MEN',
#        'Verbal Jint, AILEE', 'Jay Park, Remastered',
#        'Supreme Team, Crush', 'Lee Hyori', 'SUNMI', 'miss A',
#        "Girl's Day", 'VIXX', 'Secret', 'Geeks', 'EXID', 'EXO-K',
#        'AKMU, 로빈, 이찬혁, LEE SUHYUN', 'SUNMI, Lena', 'TAEYANG',
#        'Epik High, Joe Won Sun', 'Park Boram, ZICO', 'KYUHYUN',
#        'GD X TAEYANG', 'Block B', 'HI SUHYUN, BOBBY', 'WINNER', '2NE1',
#        'Jang Beom June', 'Crush, Punch', 'Sung Si Kyung', 'Park Hyo Shin',
#        'Jung Seung Hwan', 'M.C the Max', 'Hong Dae Kwang', 'Hyolyn',
#        'Drunken Tiger, Yoon Mirae', '15&', 'Jun Hyo Seong',
#        'TOY, Sung Si Kyung', 'Beast', 'Epik High, Younha', 'BIGBANG',
# ...

# %%
# Male Artists/Groups
male_artists = [
    "EXO", "SHINee", "Primary, Dynamicduo", "Dynamicduo, Muzie", "Roy Kim", 
    "Cho Yong Pil", "Seo In Guk", "2AM", "4MEN", "Jay Park, Remastered", 
    "Supreme Team, Crush", "TAEYANG", "KYUHYUN", "GD X TAEYANG", "Block B", 
    "WINNER", "Jang Beom June", "Sung Si Kyung", "Park Hyo Shin", 
    "Jung Seung Hwan", "M.C the Max", "Hong Dae Kwang", "Beast", "BIGBANG", 
    "BTS", "iKON", "SUPER JUNIOR", "ZICO, Babylon", "Naul", "Zion.T", 
    "JONGHYUN, Zion.T", "PSY", "ZICO", "DEAN, Gaeko", 
    "BewhY, Jay Park", "10cm", "OHHYUK", "Wanna One", "Sons of People", 
    "Woo, Loco, GRAY", "Epik High, OHHYUK", "GOT7", "NCT 127", "NCT DREAM", 
    "DAY6", "Monsta X", "Stray Kids", "RM", "MINO", "SHAUN", "ATEEZ", "Holland", 
    "SEVENTEEN", "TOMORROW X TOGETHER", "ASTRO", "Agust D", "X1", "ENHYPEN", "TREASURE",
    "G-DRAGON", "VIXX", "Geeks", "EXO-K", "TAEMIN",
    "NCT, NCT U", "HAON, VINXEN", "Lim Changjung",
    "j-hope", "Monsta X, French Montana", "ONEUS", 
    "SuperM", "NCT DREAM, HRVY", "BAEKHYUN", "PENTAGON", "AB6IX", "NCT U",
    "Lee Seung Chul", "Knock", "NU'EST W", "MeloMance", "JONGHYUN",
    "Busker Busker", "J.Y. Park", "Zion.T, DJ Dopsh, G-DRAGON"
]

# Female Artists/Groups
female_artists = [
    "4Minute", "Girls' Generation", "f(x)", "Lim Kim", "LeeHi", "DAVICHI", 
    "Lee Hyori", "SUNMI", "miss A", "Girl's Day", "Secret", 
    "EXID", "SUNMI, Lena", "Hyolyn", "Jun Hyo Seong", "Wonder Girls", "Park Boram", 
    "Baek Ji Young, Song Yu Vin", "Baek A Yeon", "BEN", "TAEYEON", "Yerin Baek", 
    "BOL4", "Gummy", "MAMAMOO", "I.O.I", "Suzy", "IZ*ONE", "(G)I-DLE", "LOONA", 
    "CHUNG HA", "JENNIE", "fromis_9", "gugudan", "Dreamcatcher", "LABOUM", 
    "ITZY", "EVERGLOW", 
    "SOMI", "Apink", "Hwa Sa", "CLC", "MOMOLAND", "BLACKPINK, Cardi B", "aespa", 
    "OH MY GIRL", "BLACKPINK, Selena Gomez", "GFRIEND", "YooA", "Lovelyz", 
    "3YE", "LISA", "ROSÉ", "STAYC", "JEON SOMI", "Weeekly", "Brave Girls",
    "Red Velvet", "TWICE", "BLACKPINK", "Yoon Mirae", "HEIZE", 
    "CHUNG HA, Nucksal", 
    "AILEE", "BoA", "Punch", "H.I.N.P (Hot Issue of Ntl. Producers)", 
    "PRODUCE 48", "Girls' Generation-Oh!GG", "IU", "AOA", "IVE", 
    "Girls Planet 999", "HyunA", "2NE1",
    "K/DA, Madison Beer, (G)I-DLE, Jaira Burns, League of Legends",
    "K/DA, (G)I-DLE, Wolftyla, Bea Miller, League of Legends", 
    "7 LOVE Minutes", "Medusa", "PRODUCE 101", "15&",
    "SEULGI, CHUNG HA, SinB, JEON SOYEON",
    "Red Velvet - IRENE & SEULGI", "BLACKPINK, Selena Gomez"
]

# Mixed-Gender Artists/Groups
mixed_gender_artists = [
    "AKMU", "Verbal Jint, AILEE", "Drunken Tiger, Yoon Mirae", 
    "Epik High, Younha", "TAEYEON, Verbal Jint", "BoA, Gaeko", "DAVICHI, Mad Clown", 
    "PSY, CL", 
    "Epik High, IU", "AKMU, IU", "KARD", "HyunA&DAWN", 
    "SUPER JUNIOR, Leslie Grace, Play-N-Skillz",
    "AKMU, 로빈, 이찬혁, LEE SUHYUN", "Epik High, Joe Won Sun", 
    "Park Boram, ZICO", "Crush, Punch", "TOY, Sung Si Kyung", 
    "Crush, ZICO", "WENDY, Eric Nam", 
    "DEAN, Yerin Baek", 
    "HEIZE, Gaeko", 
    "LeeHi, B.I", "IU, SUGA",
    "HEIZE, Yong Jun Hyung", "Crush, TAEYEON", "ZICO, IU",
    "j-hope, Becky G", "Park Kyung, Park Boram", "BTS, Nicki Minaj",
    "BTS, Halsey", "HI SUHYUN, BOBBY", "Verbal Jint, AILEE", "Zion.T, 슬기 (SEULGI)",
    "HEIZE, nafla", "HEIZE, Shin Yong Jae", "DEAN, SULLI, Rad Museum"

]


all_artists = male_artists + female_artists + mixed_gender_artists
df[~df['artist/s'].isin(all_artists)]['artist/s'].unique()
# Out:
# array([], dtype=object)

# %%
def gender_func(x): 
    if x in male_artists:
        return 'male'
    elif x in female_artists:
        return 'female'
    elif x in mixed_gender_artists:
        return 'mixed'
    else:
        return 'not_in_lists'

# %%
df['gender'] = df['artist/s'].apply(lambda x: gender_func(x))

# %%
df['gender'].value_counts()
# Out:
# gender
# male      184
# female    168
# mixed      40
# Name: count, dtype: int64

# %%
df[['gender', 'idol_group']].value_counts()
# Out:
# gender  idol_group
# male    1             115
# female  1             111
# male    0              69
# female  0              57
# mixed   0              36
#         1               4
# Name: count, dtype: int64

# %%
df.to_csv('idol_classification.csv')

# %%
no_mixed = df[df['gender'] != 'mixed']
no_mixed['gender'].value_counts()
# Out:
# gender
# male      184
# female    168
# Name: count, dtype: int64

# %%
no_mixed.to_csv('no_mixed.csv')
